# %% [markdown]
# ### I. Import Required Dependecies

# %%
import os
import glob
from IPython.display import Image as IPImage
import pandas as pd             # Pandas
import numpy as np              # NumPy
import matplotlib.pyplot as plt # Matplotlib
import seaborn as sns           # Seaborn
from PIL import Image           # Pillow
import pandas as pd             # Pandas
import numpy as np              # NumPy
import matplotlib.pyplot as plt # Matplotlib
import seaborn as sns           # Seaborn

# scikit-learn
from sklearn.metrics import confusion_matrix, classification_report

# Keras
import keras
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
# TensorFlow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import plot_model

# Keras
from keras.layers import Flatten, Dense, Activation, Dropout
from keras import models, optimizers
from keras.models import Sequential
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam, Adamax
from keras.preprocessing.image import ImageDataGenerator
from keras.models import model_from_json
from keras.regularizers import l2
from keras.layers import Conv2D, MaxPooling2D
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications import DenseNet121
from keras.applications.densenet import DenseNet121, preprocess_input

# scikit-learn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### II. Read Dataset

# %%
# @title
import zipfile
import os

def unzip_file(zip_file_path, output_dir):
    """
    Unzips the specified zip file into the specified output directory.

    :param zip_file_path: Path to the zip file.
    :param output_dir: Path to the directory where files should be extracted.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(output_dir)
        print(f"Extracted all files to {output_dir}")

# Example usage:
zip_file_path = '/content/drive/MyDrive/dataset/archive (9).zip'
output_dir = '/content/drive/MyDrive/dataset/archive'
unzip_file(zip_file_path, output_dir)
# Out:
# Extracted all files to /content/drive/MyDrive/dataset/archive

# %%
# @title
os.listdir('/content/drive/MyDrive/dataset/archive/Dataset_BUSI_with_GT')
# Out:
# ['benign', 'malignant', 'normal']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Directory Names Containing Training Data**

# %%
# Define the path to the directory containing the images for training
train_data = '/content/drive/MyDrive/dataset/archive/Dataset_BUSI_with_GT'

# Create a Pandas DataFrame with a single column
# The column is populated with the list of file/directory names in the 'train_data' directory
pd.DataFrame(
    os.listdir(train_data),
    columns=['File Name']
)
# Out:
#    File Name
# 0     benign
# 1  malignant
# 2     normal

# %% [markdown]
# **Directory Paths Containing Training Data**

# %%
# Get a list of the file paths in the 'train_data' directory
train_files = [i for i in glob.glob(train_data + "/*/*")]

# Randomly shuffle the list of file paths
np.random.shuffle(train_files)

# Extract labels from the directory names of each file path
labels = [os.path.dirname(i).split("/")[-1] for i in train_files]

# Combine file paths & its corresponding labels into a list of tuples
data = zip(train_files, labels)

# Create a Pandas DataFrame with 2 columns
# "Path" column contains file paths, & "Label" column contains corresponding labels
training_data = pd.DataFrame(data, columns=["Path", "Label"])

# Display the contents of the DataFrame
training_data
# Out:
#                                                    Path      Label
# 0     /content/drive/MyDrive/dataset/archive/Dataset...  malignant
# 1     /content/drive/MyDrive/dataset/archive/Dataset...     benign
# 2     /content/drive/MyDrive/dataset/archive/Dataset...     normal
# 3     /content/drive/MyDrive/dataset/archive/Dataset...  malignant
# 4     /content/drive/MyDrive/dataset/archive/Dataset...     benign
# ...                                                 ...        ...
# 1043  /content/drive/MyDrive/dataset/archive/Dataset...     normal
# 1044  /content/drive/MyDrive/dataset/archive/Dataset...  malignant
# 1045  /content/drive/MyDrive/dataset/archive/Dataset...  malignant
# 1046  /content/drive/MyDrive/dataset/archive/Dataset...  malignant
# 1047  /content/drive/MyDrive/dataset/archive/Dataset...     normal
#
# [1048 rows x 2 columns]

# %% [markdown]
# ### III. Data Visualization

# %%
# Create a countplot() using Seaborn, where x-axis represents the "Label" column of the training_data DataFrame
ax = sns.countplot(x=training_data["Label"])

# Display count inside each bar as integers
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points', fontsize=8)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a title with the total count of files
plt.title(f'Total Files: {len(training_data)}', pad=10)

# Show the plot
plt.show()

# %% [markdown]
# ### IV. Collect Data Paths & Labels from Directory Structure

# %%
data_paths = []
labels = []

main_dirs = os.listdir(train_data)
for folder_name in main_dirs:
    folder_path = os.path.join(train_data, folder_name)
    files = os.listdir(folder_path)
    for file in files:
        file_path = os.path.join(folder_path, file)
        data_paths.append(file_path)
        labels.append(folder_name)

# %% [markdown]
# ### V. Data Preprocessing

# %%
# Set the batch size for training
batch_size = 16

# Define the target image size for preprocessing
image_size = (256, 256)

# Specify the number of color channels in the images (3 for RGB)
num_channels = 3

# Create the image shape tuple based on the specified size and channels
image_shape = (image_size[0], image_size[1], num_channels)

# Create a Pandas Series containing file paths with the name 'Path'
data_dirs = pd.Series(data_paths, name='Path')

# Create a Pandas Series containing corresponding labels with the name 'Label'
classes = pd.Series(labels, name='Label')

def preprocess_image(img):
    return img

# Split the data into training and validation-test sets
train_df, val_test_df = train_test_split(
    training_data,
    train_size=0.8,
    shuffle=True,
    random_state=123
)

# Further split the validation-test set into validation and test sets
val_df, test_df = train_test_split(
    val_test_df,
    train_size=0.5,
    shuffle=True,
    random_state=123
)

# ImageDataGenerator configuration
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,
    rescale=1.0/255
)

# Convert the 'Label' column to string type
train_df['Label'] = train_df['Label'].astype(str)
val_df['Label'] = val_df['Label'].astype(str)

# Create generators for training, validation, and testing
train_generator = datagen.flow_from_dataframe(
    train_df,
    x_col='Path',
    y_col='Label',
    target_size=image_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size
)

valid_generator = datagen.flow_from_dataframe(
    val_df,
    x_col='Path',
    y_col='Label',
    target_size=image_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size
)
# Out:
# Found 838 validated image filenames belonging to 3 classes.
# Found 105 validated image filenames belonging to 3 classes.

# %% [markdown]
# **Display Class Names**

# %%
# Get the class indices (mapping of the class names to numerical indices) from the training generator
class_indices = train_generator.class_indices

# Display the keys (class names) from the class_indices dictionary
class_indices.keys()
# Out:
# dict_keys(['benign', 'malignant', 'normal'])

# %%
# Initialize an empty list to store class labels
labels = []

# Iterate through the keys (class names) in the class_indices dictionary
for key in class_indices.keys():
    labels.append(key)  # Append each class name to the labels list

# Calculate the total no. of unique labels
total_labels = len(labels)

# Print the list of class labels and the total no. of unique labels
print("Labels: ", labels)
print("\nTotal no. of unique labels:", total_labels)
# Out:
# Labels:  ['benign', 'malignant', 'normal']
#
# Total no. of unique labels: 3

# %% [markdown]
# **Visualize a Subset of Images from the Training Set**

# %%
# Set the number of rows and columns for the subplot grid
no_of_rows = 2
no_of_columns = 4

# Create a subplot grid with the specified number of rows and columns
fig, axes = plt.subplots(no_of_rows, no_of_columns, figsize=(12, 8))

# Iterate through the rows
for i in range(no_of_rows):
    # Iterate through the columns
    for j in range(no_of_columns):
        # Calculate the index for accessing the data
        index = i * no_of_columns + j

        # Check if the index is within the bounds of the data
        if index < len(training_data):

            # Open the image using the PIL library
            im = Image.open(training_data.iloc[index]['Path'])

            # Convert the PIL image to a NumPy array
            img = np.array(im)

            # Print the shape of the image array
            print(img.shape)

            # Display the image on the subplot at position (i, j)
            axes[i, j].imshow(img)

            # Turn off axis labels for better visualization
            axes[i, j].axis('off')

            # Get the label for the current image and display it as text
            label = training_data.iloc[index]['Label']
            axes[i, j].text(0.5, -0.1, label, ha='center', transform=axes[i, j].transAxes)

# Show the entire subplot grid
plt.show()
# Out:
# (587, 801)
# (469, 557)
# (485, 501, 3)
# (472, 511, 3)
# (462, 560)
# (470, 568, 3)
# (485, 733)
# (471, 552, 3)

# %% [markdown]
# ### VI. Build Model

# %%
# Load DenseNet-121 with pre-trained weights
base_model = DenseNet121(
    weights='/content/drive/MyDrive/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5',
    include_top=False,
    input_shape=(256, 256, 3)
)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create model
model = Sequential()

# Add the pre-trained DenseNet-121 base model
model.add(base_model)

# Flatten the output of the base model
model.add(Flatten())

# Add fully connected layers with dropout for regularization
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
# Additional layers for classification
model.add(Dense(3, activation='softmax'))

# Display the summary of the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 8, 8, 1024)        7037504
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 1024)              67109888
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 74846851 (285.52 MB)
# Trainable params: 67809347 (258.67 MB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %% [markdown]
# **Visualize the Neural Network Architecture**

# %%
# Specify the file path for saving the visualization image
model_visualization_path = "/content/drive/MyDrive/nn_architecture9.png"

# Plot the model and save the visualization image
plot_model(model, to_file=model_visualization_path, show_shapes=True, show_layer_names=True)

# Display the visualization image
IPImage(filename=model_visualization_path)

# %% [markdown]
# **Create Model Checkpoint Callback to Save Best Model**

# %%
# Define the path to save the best model checkpoint
checkpoint_path = "/content/drive/MyDrive/checkpoint/model9.h5"
# Create a ModelCheckpoint callback
# This callback saves the model when validation accuracy improves
checkpoint = ModelCheckpoint(
    checkpoint_path,
    monitor='val_accuracy',  # Monitor validation accuracy
    save_best_only=True,     # Save only the best model
    mode='max',              # Save based on the maximum validation accuracy
    verbose=1                # Display progress information
)

# %% [markdown]
# ### VII. Compile Model

# %%
# Compile the model with the Adam optimizer, categorical crossentropy loss, and accuracy metric
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # Categorical crossentropy loss for multi-class classification
    metrics=['accuracy']              # Monitor accuracy during training
)

# %% [markdown]
# ### VIII. Train Model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define the EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',    # Metric to be monitored
    patience=5,            # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Whether to restore model weights from the epoch with the best value of the monitored quantity
)

# Train the model using the fit() method
history = model.fit(
    train_generator,                                   # Training data generator
    steps_per_epoch=train_generator.samples // train_generator.batch_size,  # Number of steps per epoch
    epochs=35,                                         # Number of training epochs
    validation_data=valid_generator,                   # Validation data generator
    validation_steps=valid_generator.samples // valid_generator.batch_size,  # Number of validation steps
    callbacks=[checkpoint, early_stopping]             # List of callbacks, including ModelCheckpoint and EarlyStopping
)
# Out:
# Epoch 1/35
# 52/52 [==============================] - ETA: 0s - loss: 8.1195 - accuracy: 0.4197
# Epoch 1: val_accuracy improved from -inf to 0.27083, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 52/52 [==============================] - 447s 8s/step - loss: 8.1195 - accuracy: 0.4197 - val_loss: 2.0406 - val_accuracy: 0.2708
# Epoch 2/35
# 52/52 [==============================] - ETA: 0s - loss: 3.6591 - accuracy: 0.4294
# Epoch 2: val_accuracy improved from 0.27083 to 0.53125, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 15s 293ms/step - loss: 3.6591 - accuracy: 0.4294 - val_loss: 1.1227 - val_accuracy: 0.5312
# Epoch 3/35
# 52/52 [==============================] - ETA: 0s - loss: 2.0580 - accuracy: 0.4453
# Epoch 3: val_accuracy improved from 0.53125 to 0.60417, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 15s 293ms/step - loss: 2.0580 - accuracy: 0.4453 - val_loss: 0.9830 - val_accuracy: 0.6042
# Epoch 4/35
# 52/52 [==============================] - ETA: 0s - loss: 1.3442 - accuracy: 0.5012
# Epoch 4: val_accuracy did not improve from 0.60417
# 52/52 [==============================] - 11s 206ms/step - loss: 1.3442 - accuracy: 0.5012 - val_loss: 0.7834 - val_accuracy: 0.5729
# Epoch 5/35
# 52/52 [==============================] - ETA: 0s - loss: 1.1107 - accuracy: 0.5170
# Epoch 5: val_accuracy improved from 0.60417 to 0.67708, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 24s 470ms/step - loss: 1.1107 - accuracy: 0.5170 - val_loss: 0.6777 - val_accuracy: 0.6771
# Epoch 6/35
# 52/52 [==============================] - ETA: 0s - loss: 0.9717 - accuracy: 0.5560
# Epoch 6: val_accuracy did not improve from 0.67708
# 52/52 [==============================] - 12s 223ms/step - loss: 0.9717 - accuracy: 0.5560 - val_loss: 0.6147 - val_accuracy: 0.6771
# Epoch 7/35
# 52/52 [==============================] - ETA: 0s - loss: 0.8136 - accuracy: 0.6314
# Epoch 7: val_accuracy improved from 0.67708 to 0.68750, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 23s 444ms/step - loss: 0.8136 - accuracy: 0.6314 - val_loss: 0.5956 - val_accuracy: 0.6875
# Epoch 8/35
# 52/52 [==============================] - ETA: 0s - loss: 0.7794 - accuracy: 0.6180
# Epoch 8: val_accuracy improved from 0.68750 to 0.75000, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 16s 298ms/step - loss: 0.7794 - accuracy: 0.6180 - val_loss: 0.5257 - val_accuracy: 0.7500
# Epoch 9/35
# 52/52 [==============================] - ETA: 0s - loss: 0.7556 - accuracy: 0.6350
# Epoch 9: val_accuracy did not improve from 0.75000
# 52/52 [==============================] - 9s 177ms/step - loss: 0.7556 - accuracy: 0.6350 - val_loss: 0.5342 - val_accuracy: 0.7396
# Epoch 10/35
# 52/52 [==============================] - ETA: 0s - loss: 0.6753 - accuracy: 0.7032
# Epoch 10: val_accuracy improved from 0.75000 to 0.80208, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 31s 595ms/step - loss: 0.6753 - accuracy: 0.7032 - val_loss: 0.4855 - val_accuracy: 0.8021
# Epoch 11/35
# 52/52 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.7105
# Epoch 11: val_accuracy improved from 0.80208 to 0.84375, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 21s 411ms/step - loss: 0.5979 - accuracy: 0.7105 - val_loss: 0.3960 - val_accuracy: 0.8438
# Epoch 12/35
# 52/52 [==============================] - ETA: 0s - loss: 0.5949 - accuracy: 0.7275
# Epoch 12: val_accuracy did not improve from 0.84375
# 52/52 [==============================] - 10s 185ms/step - loss: 0.5949 - accuracy: 0.7275 - val_loss: 0.4579 - val_accuracy: 0.8229
# Epoch 13/35
# 52/52 [==============================] - ETA: 0s - loss: 0.5731 - accuracy: 0.7494
# Epoch 13: val_accuracy improved from 0.84375 to 0.86458, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 25s 492ms/step - loss: 0.5731 - accuracy: 0.7494 - val_loss: 0.3739 - val_accuracy: 0.8646
# Epoch 14/35
# 52/52 [==============================] - ETA: 0s - loss: 0.4800 - accuracy: 0.8163
# Epoch 14: val_accuracy improved from 0.86458 to 0.88542, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 23s 452ms/step - loss: 0.4800 - accuracy: 0.8163 - val_loss: 0.3279 - val_accuracy: 0.8854
# Epoch 15/35
# 52/52 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8005
# Epoch 15: val_accuracy improved from 0.88542 to 0.89583, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 26s 499ms/step - loss: 0.4559 - accuracy: 0.8005 - val_loss: 0.3241 - val_accuracy: 0.8958
# Epoch 16/35
# 52/52 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8297
# Epoch 16: val_accuracy did not improve from 0.89583
# 52/52 [==============================] - 10s 192ms/step - loss: 0.4209 - accuracy: 0.8297 - val_loss: 0.3816 - val_accuracy: 0.8646
# Epoch 17/35
# 52/52 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8175
# Epoch 17: val_accuracy improved from 0.89583 to 0.91667, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 25s 477ms/step - loss: 0.4160 - accuracy: 0.8175 - val_loss: 0.2597 - val_accuracy: 0.9167
# Epoch 18/35
# 52/52 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.8540
# Epoch 18: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 10s 192ms/step - loss: 0.3476 - accuracy: 0.8540 - val_loss: 0.2716 - val_accuracy: 0.8958
# Epoch 19/35
# 52/52 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8589
# Epoch 19: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 11s 211ms/step - loss: 0.3381 - accuracy: 0.8589 - val_loss: 0.2622 - val_accuracy: 0.8958
# Epoch 20/35
# 52/52 [==============================] - ETA: 0s - loss: 0.3335 - accuracy: 0.8723
# Epoch 20: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 10s 200ms/step - loss: 0.3335 - accuracy: 0.8723 - val_loss: 0.2520 - val_accuracy: 0.8958
# Epoch 21/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2998 - accuracy: 0.8893
# Epoch 21: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 9s 178ms/step - loss: 0.2998 - accuracy: 0.8893 - val_loss: 0.3600 - val_accuracy: 0.8750
# Epoch 22/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9100
# Epoch 22: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 10s 191ms/step - loss: 0.2531 - accuracy: 0.9100 - val_loss: 0.3035 - val_accuracy: 0.9167
# Epoch 23/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.8954
# Epoch 23: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 10s 201ms/step - loss: 0.2686 - accuracy: 0.8954 - val_loss: 0.3982 - val_accuracy: 0.9167
# Epoch 24/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9173
# Epoch 24: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 9s 172ms/step - loss: 0.2016 - accuracy: 0.9173 - val_loss: 0.2930 - val_accuracy: 0.8958
# Epoch 25/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.8990
# Epoch 25: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 10s 186ms/step - loss: 0.2537 - accuracy: 0.8990 - val_loss: 0.2424 - val_accuracy: 0.9062
# Epoch 26/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9270
# Epoch 26: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 10s 183ms/step - loss: 0.2037 - accuracy: 0.9270 - val_loss: 0.3685 - val_accuracy: 0.9167
# Epoch 27/35
# 52/52 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9319
# Epoch 27: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 9s 179ms/step - loss: 0.1867 - accuracy: 0.9319 - val_loss: 0.3067 - val_accuracy: 0.8750
# Epoch 28/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.9209
# Epoch 28: val_accuracy did not improve from 0.91667
# 52/52 [==============================] - 9s 174ms/step - loss: 0.2121 - accuracy: 0.9209 - val_loss: 0.3246 - val_accuracy: 0.8958
# Epoch 29/35
# 52/52 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9465
# Epoch 29: val_accuracy improved from 0.91667 to 0.94792, saving model to /content/drive/MyDrive/checkpoint/model9.h5
# 52/52 [==============================] - 26s 512ms/step - loss: 0.1693 - accuracy: 0.9465 - val_loss: 0.2242 - val_accuracy: 0.9479
# Epoch 30/35
# 52/52 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9453
# Epoch 30: val_accuracy did not improve from 0.94792
# 52/52 [==============================] - 10s 200ms/step - loss: 0.1410 - accuracy: 0.9453 - val_loss: 0.2467 - val_accuracy: 0.8854
# Epoch 31/35
# 52/52 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9197
# Epoch 31: val_accuracy did not improve from 0.94792
# 52/52 [==============================] - 11s 212ms/step - loss: 0.2058 - accuracy: 0.9197 - val_loss: 0.2737 - val_accuracy: 0.9375
# Epoch 32/35
# 52/52 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9331
# Epoch 32: val_accuracy did not improve from 0.94792
# 52/52 [==============================] - 11s 210ms/step - loss: 0.1714 - accuracy: 0.9331 - val_loss: 0.3149 - val_accuracy: 0.9167
# Epoch 33/35
# 52/52 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9647
# Epoch 33: val_accuracy did not improve from 0.94792
# 52/52 [==============================] - 9s 171ms/step - loss: 0.1160 - accuracy: 0.9647 - val_loss: 0.2880 - val_accuracy: 0.9271
# Epoch 34/35
# 52/52 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9440
# Epoch 34: val_accuracy did not improve from 0.94792
# 52/52 [==============================] - 10s 190ms/step - loss: 0.1752 - accuracy: 0.9440 - val_loss: 0.4242 - val_accuracy: 0.8958

# %% [markdown]
# **Display Training History**

# %%
# Create a Pandas DataFrame containing the training history (metrics) of the model
train_history = pd.DataFrame(history.history)

# Add a new column 'Epoch' with values from 1 to the number of epochs
train_history['Epoch'] = range(1, len(train_history) + 1)

# Reorder columns for clarity
train_history = train_history[['Epoch', 'loss', 'accuracy', 'val_loss', 'val_accuracy']]

# Display the DataFrame
train_history
# Out:
#     Epoch      loss  accuracy  val_loss  val_accuracy
# 0       1  8.119510  0.419708  2.040570      0.270833
# 1       2  3.659114  0.429440  1.122736      0.531250
# 2       3  2.058047  0.445255  0.983035      0.604167
# 3       4  1.344179  0.501217  0.783405      0.572917
# 4       5  1.110696  0.517032  0.677652      0.677083
# 5       6  0.971686  0.555961  0.614708      0.677083
# 6       7  0.813642  0.631387  0.595554      0.687500
# 7       8  0.779421  0.618005  0.525735      0.750000
# 8       9  0.755635  0.635036  0.534158      0.739583
# 9      10  0.675318  0.703163  0.485501      0.802083
# 10     11  0.597918  0.710462  0.395993      0.843750
# 11     12  0.594921  0.727494  0.457894      0.822917
# 12     13  0.573060  0.749392  0.373856      0.864583
# 13     14  0.479972  0.816302  0.327909      0.885417
# 14     15  0.455939  0.800487  0.324071      0.895833
# 15     16  0.420880  0.829684  0.381628      0.864583
# 16     17  0.416013  0.817518  0.259678      0.916667
# 17     18  0.347596  0.854015  0.271614      0.895833
# 18     19  0.338148  0.858881  0.262208      0.895833
# 19     20  0.333498  0.872263  0.252004      0.895833
# 20     21  0.299805  0.889294  0.359990      0.875000
# 21     22  0.253108  0.909976  0.303533      0.916667
# 22     23  0.268615  0.895377  0.398197      0.916667
# 23     24  0.201572  0.917275  0.292961      0.895833
# 24     25  0.253750  0.899027  0.242371      0.906250
# 25     26  0.203721  0.927007  0.368547      0.916667
# 26     27  0.186691  0.931874  0.306714      0.875000
# 27     28  0.212106  0.920925  0.324606      0.895833
# 28     29  0.169291  0.946472  0.224184      0.947917
# 29     30  0.140978  0.945255  0.246747      0.885417
# 30     31  0.205800  0.919708  0.273707      0.937500
# 31     32  0.171448  0.933090  0.314858      0.916667
# 32     33  0.115956  0.964720  0.287998      0.927083
# 33     34  0.175153  0.944039  0.424198      0.895833

# %% [markdown]
# ### IX. Evaluate Model (Train & Validation Set)

# %%
# Evaluate the model on the train set
train_loss, train_accuracy = model.evaluate(train_generator, steps=train_generator.samples // train_generator.batch_size)

# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(valid_generator, steps=valid_generator.samples // valid_generator.batch_size)

# Convert accuracy to percentage
train_accuracy_percentage = train_accuracy * 100
val_accuracy_percentage = val_accuracy * 100

# Create a Pandas DataFrame to display the results
evaluation_results = pd.DataFrame({
    'Set': ['Train', 'Validation'],
    'Loss': [train_loss, val_loss],
    'Accuracy': [f'{train_accuracy_percentage:.2f}%', f'{val_accuracy_percentage:.2f}%']
})

# Display the evaluation results DataFrame
evaluation_results
# Out:
# 52/52 [==============================] - 8s 161ms/step - loss: 0.0588 - accuracy: 0.9844
# 6/6 [==============================] - 1s 129ms/step - loss: 0.1332 - accuracy: 0.9583
#           Set      Loss Accuracy
# 0       Train  0.058762   98.44%
# 1  Validation  0.133207   95.83%

# %% [markdown]
# **Plot Loss & Accuracy**

# %%
# Plotting the training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_history['loss'], label='Training Loss')
plt.plot(train_history['val_loss'], label='Validation Loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_history['accuracy'], label='Training Accuracy')
plt.plot(train_history['val_accuracy'], label='Validation Accuracy')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
